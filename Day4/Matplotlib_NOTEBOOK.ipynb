# %% [markdown]
# # Matplotlib

# %% [markdown]
# <img src="https://raw.githubusercontent.com/fperez/blog/master/fig/johnhunter-head.jpg" width="200">

# %% [markdown]
# ### Stateful approach

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1, 3, 2, 4])
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([1, 2, 3, 3])
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([1, 2, 3, 3])
plt.grid(True)
plt.show()

# %%
plt.plot([1, 3, 2, 4])
plt.plot([1, 2, 3, 3])
plt.grid(True)
plt.axis([1, 4, 1, 6])
plt.show()

# %%
plt.plot([1, 3, 2, 4], label='I am boring', color='blue', 
         linestyle='dashed')
plt.plot([1, 2, 3, 3], label="legend", color='red')
plt.xlabel('This is the X axis')
plt.ylabel('This is the Y axis')
plt.title('I am title!')
plt.legend()
#plt.legend(['I am', 'legend'])
plt.show()

# %%
# Saving plot, automatically creats a file according the pripona that you add. Magic!!
plt.plot([1, 0, 2, 4, 6], label='I am boring', color='blue', 
         linestyle='dashed')
plt.plot([1, 2, 3, 3, 4], label="legend", color='red')
plt.xlabel('This is the X axis')
plt.ylabel('This is the Y axis')
plt.title('I am title!')
plt.legend()
plt.xticks([1, 2, 3, 4, 5])
#plt.legend(['I am', 'legend'])
plt.savefig('plot123.jpg', dpi=300)

# %%
plt.plot([1, 3, 2, 4], label='I am')
plt.plot([1, 2, 3, 3], label="legend")
plt.xlabel('This is the X axis')
plt.ylabel('This is the Y axis')
plt.title('I am title!')
plt.legend()
plt.xticks([1,2,3]) # changing the ticks (kliste) - 
plt.yticks([1,2,3,4])
plt.show()

# %%
y = np.random.randn(100000)
plt.hist(y)
plt.show()

# %%
y = np.random.randn(100000)
plt.hist(y, bins=300)
plt.show()

# %%
# statefull approach

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

# plt.figure(1)
plt.subplot(211) # two rows, 1 column and first plot
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212) # two rows, 1 column and second plot
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
# plt.figure(1)
plt.subplot(121) # 1 row, 2 columns, 1.st graf
plt.plot([1, 2, 3, 4, 5])

plt.subplot(122) # two rows, 1 column and second plot
plt.plot([10, 11, 12, 5, 6])
plt.show()

# %%
# plt.figure(1)
plt.subplot(211) # 1 row, 2 columns, 1.st graf
plt.plot([1, 2, 3, 4, 5])

plt.subplot(223) # 
plt.plot([10, 11, 12, 5, 6])

plt.subplot(224) # 
plt.plot([10, 11, 12, 5, 6])
plt.show()

# %%
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
plt.show()

# %% [markdown]
# ### Stateless approach
# * object oriented approach
# * convenien because you can work on many plots at the same time
# * create figure, create plots and then fill them as you wish

# %% [markdown]
# <img src="https://files.realpython.com/media/fig_map.bc8c7cabd823.png" width='300'>

# %%
fig, ax = plt.subplots() # default: (nrows=1, ncols=1)
ax.plot([1, 2, 3], [1, 2, 3])
ax.set(title='Title', xticks=[1,2,3])
#ax.set_title, ax.set_xticks
plt.show()

# %%
# define the plots as an objects
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)
fig.subplots_adjust(hspace = 0.4) # adjust horizontal space among them 

# communicate with each plot individually
ax1.plot([1, 2, 3], [1, 2, 3], color='red')
ax1.grid(True)
ax1.set_xticks([1,2,3])
ax2.plot([1, 2, 3], [3, 2, 1])
ax2.set_title("Some title")
plt.show()

# %% [markdown]
# Other well known plotting packages: **Seaborn**, **Bokeh**, **Plotly**.
